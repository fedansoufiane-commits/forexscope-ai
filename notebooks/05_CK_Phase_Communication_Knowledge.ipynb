# %% [markdown]
# # C/K-Phase: Communication & Knowledge
#
# Dieses Notebook ist als Struktur für die weitere Ausarbeitung der QUA3CK-Phase vorbereitet. Die aktuelle Pflichtabgabe fokussiert sich auf die Q-Phase; diese Datei dient als Erweiterung für das spätere Referat und Handout.

# %% [markdown]
# ## Ziel der C/K-Phase
#
# Wird im weiteren Projektverlauf ausgearbeitet.

# %% [markdown]
# ## Kommunikation der Ergebnisse
#
# Wird im weiteren Projektverlauf ausgearbeitet.

# %% [markdown]
# ## Wissensgewinn für Nutzer
#
# Wird im weiteren Projektverlauf ausgearbeitet.

# %% [markdown]
# ## Grenzen und Transparenz
#
# Wird im weiteren Projektverlauf ausgearbeitet.

# %% [markdown]
# ## Präsentations- und Handout-Bezug
#
# Wird im weiteren Projektverlauf ausgearbeitet.

# %% [markdown]
# ## Nächste Schritte
#
# Wird im weiteren Projektverlauf ausgearbeitet.
